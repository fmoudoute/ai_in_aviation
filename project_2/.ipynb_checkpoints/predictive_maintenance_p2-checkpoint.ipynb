# %% [markdown]
# # Landing Gear Failure Prediction

# %%
import pandas as pd
import numpy as np

# Load datasets (adjust paths if needed)
bogie_data = pd.read_csv('./data/LGD_S_DATASET_1_BogiePitchTrimmer_PressureDrop_OverFlightCycles.csv')
tyre_pressure_data = pd.read_csv('./data/LGD_S_DATASET_2_TyrePressureIndicator_PressureDrop_OverFlightCycles.csv')
temperature_rise_data = pd.read_csv('./data/LGD_S_DATASET_3_TyrePressureIndicator_TemperatureRise_DuringLanding.csv')
brake_temperature_data = pd.read_csv('./data/LGD_S_DATASET_4_LandingGearBrakes_MaxTemperature_OverFlightCycles.csv')
brake_deceleration_data_takeoff = pd.read_csv('./data/LGD_S_DATASET_5_LandingGearBrakes_Deceleration_DuringTakeoff.csv')
brake_deceleration_data_flight = pd.read_csv('./data/LGD_S_DATASET_6_LandingGearBrakes_Deceleration_OverFlightCycles.csv')

# %%
# Extract relevant columns for the Bogie Pitch Trimmer dataset
bogie_data = bogie_data[['set_id', 'row_id', 'pressure_1', 'pressure_2', 'temperature_1', 'temperature_2', 'position_1', 'position_2', 'oil_level_1', 'oil_level_2']]

# Split the features and target (e.g., predicting pressure_1 as the failure variable)
X_bogie = bogie_data.drop(columns=['set_id', 'row_id', 'pressure_1'])  # Drop the target column for features
y_bogie = bogie_data['pressure_1']  # Target: 'pressure_1' or any other column related to failure

# Scale features for LSTM (StandardScaler)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_bogie_scaled = scaler.fit_transform(X_bogie)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

# Reshape data for LSTM: (samples, timesteps, features)
X_bogie_scaled = X_bogie_scaled.reshape((X_bogie_scaled.shape[0], 1, X_bogie_scaled.shape[1]))  # Timesteps=1 for each row

# Create and compile the LSTM model
model = Sequential()
model.add(LSTM(100, input_shape=(X_bogie_scaled.shape[1], X_bogie_scaled.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))  # Sigmoid for binary classification (failure or not)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
history = model.fit(X_bogie_scaled, y_bogie, epochs=200, batch_size=64, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/200
# /Users/frantzmoudoute/anaconda3/envs/jax-env/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 500/500 - 2s - 4ms/step - accuracy: 0.0000e+00 - loss: -2.6771e+04 - val_accuracy: 0.0000e+00 - val_loss: -4.8250e+04
# Epoch 2/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -6.3590e+04 - val_accuracy: 0.0000e+00 - val_loss: -7.8529e+04
# Epoch 3/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -9.3045e+04 - val_accuracy: 0.0000e+00 - val_loss: -1.0740e+05
# Epoch 4/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.2173e+05 - val_accuracy: 0.0000e+00 - val_loss: -1.3581e+05
# Epoch 5/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.5006e+05 - val_accuracy: 0.0000e+00 - val_loss: -1.6401e+05
# Epoch 6/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.7807e+05 - val_accuracy: 0.0000e+00 - val_loss: -1.9207e+05
# Epoch 7/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.0611e+05 - val_accuracy: 0.0000e+00 - val_loss: -2.2008e+05
# Epoch 8/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.3438e+05 - val_accuracy: 0.0000e+00 - val_loss: -2.4808e+05
# Epoch 9/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.6221e+05 - val_accuracy: 0.0000e+00 - val_loss: -2.7604e+05
# Epoch 10/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.9009e+05 - val_accuracy: 0.0000e+00 - val_loss: -3.0399e+05
# Epoch 11/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.1806e+05 - val_accuracy: 0.0000e+00 - val_loss: -3.3192e+05
# Epoch 12/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.4597e+05 - val_accuracy: 0.0000e+00 - val_loss: -3.5985e+05
# Epoch 13/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.7412e+05 - val_accuracy: 0.0000e+00 - val_loss: -3.8779e+05
# Epoch 14/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.0198e+05 - val_accuracy: 0.0000e+00 - val_loss: -4.1572e+05
# Epoch 15/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.3003e+05 - val_accuracy: 0.0000e+00 - val_loss: -4.4366e+05
# Epoch 16/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.5780e+05 - val_accuracy: 0.0000e+00 - val_loss: -4.7158e+05
# Epoch 17/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.8611e+05 - val_accuracy: 0.0000e+00 - val_loss: -4.9952e+05
# Epoch 18/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -5.1383e+05 - val_accuracy: 0.0000e+00 - val_loss: -5.2745e+05
# Epoch 19/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -5.4201e+05 - val_accuracy: 0.0000e+00 - val_loss: -5.5539e+05
# Epoch 20/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -5.6948e+05 - val_accuracy: 0.0000e+00 - val_loss: -5.8330e+05
# Epoch 21/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -5.9743e+05 - val_accuracy: 0.0000e+00 - val_loss: -6.1122e+05
# Epoch 22/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -6.2558e+05 - val_accuracy: 0.0000e+00 - val_loss: -6.3915e+05
# Epoch 23/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -6.5342e+05 - val_accuracy: 0.0000e+00 - val_loss: -6.6708e+05
# Epoch 24/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -6.8215e+05 - val_accuracy: 0.0000e+00 - val_loss: -6.9503e+05
# Epoch 25/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -7.0939e+05 - val_accuracy: 0.0000e+00 - val_loss: -7.2295e+05
# Epoch 26/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -7.3738e+05 - val_accuracy: 0.0000e+00 - val_loss: -7.5088e+05
# Epoch 27/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -7.6434e+05 - val_accuracy: 0.0000e+00 - val_loss: -7.7878e+05
# Epoch 28/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -7.9285e+05 - val_accuracy: 0.0000e+00 - val_loss: -8.0671e+05
# Epoch 29/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -8.2126e+05 - val_accuracy: 0.0000e+00 - val_loss: -8.3464e+05
# Epoch 30/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -8.4887e+05 - val_accuracy: 0.0000e+00 - val_loss: -8.6257e+05
# Epoch 31/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -8.7743e+05 - val_accuracy: 0.0000e+00 - val_loss: -8.9052e+05
# Epoch 32/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -9.0525e+05 - val_accuracy: 0.0000e+00 - val_loss: -9.1845e+05
# Epoch 33/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -9.3236e+05 - val_accuracy: 0.0000e+00 - val_loss: -9.4636e+05
# Epoch 34/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -9.6147e+05 - val_accuracy: 0.0000e+00 - val_loss: -9.7431e+05
# Epoch 35/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -9.8945e+05 - val_accuracy: 0.0000e+00 - val_loss: -1.0022e+06
# Epoch 36/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.0169e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.0302e+06
# Epoch 37/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.0444e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.0581e+06
# Epoch 38/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.0728e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.0860e+06
# Epoch 39/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.1006e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.1139e+06
# Epoch 40/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.1290e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.1419e+06
# Epoch 41/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.1570e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.1698e+06
# Epoch 42/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.1847e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.1977e+06
# Epoch 43/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.2125e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.2257e+06
# Epoch 44/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.2403e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.2536e+06
# Epoch 45/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.2690e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.2815e+06
# Epoch 46/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.2975e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.3095e+06
# Epoch 47/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.3251e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.3374e+06
# Epoch 48/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.3519e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.3653e+06
# Epoch 49/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.3796e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.3932e+06
# Epoch 50/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.4088e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.4212e+06
# Epoch 51/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.4371e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.4491e+06
# Epoch 52/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.4641e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.4770e+06
# Epoch 53/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.4928e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.5050e+06
# Epoch 54/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.5196e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.5329e+06
# Epoch 55/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.5472e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.5608e+06
# Epoch 56/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.5766e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.5887e+06
# Epoch 57/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.6042e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.6167e+06
# Epoch 58/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.6320e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.6446e+06
# Epoch 59/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.6584e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.6725e+06
# Epoch 60/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.6881e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.7005e+06
# Epoch 61/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.7146e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.7284e+06
# Epoch 62/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.7434e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.7563e+06
# Epoch 63/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.7720e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.7842e+06
# Epoch 64/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.7989e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.8122e+06
# Epoch 65/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.8272e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.8401e+06
# Epoch 66/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.8563e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.8680e+06
# Epoch 67/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.8833e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.8960e+06
# Epoch 68/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.9101e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.9239e+06
# Epoch 69/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.9390e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.9518e+06
# Epoch 70/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.9670e+06 - val_accuracy: 0.0000e+00 - val_loss: -1.9797e+06
# Epoch 71/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -1.9938e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.0076e+06
# Epoch 72/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.0237e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.0356e+06
# Epoch 73/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.0517e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.0635e+06
# Epoch 74/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.0769e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.0914e+06
# Epoch 75/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.1070e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.1194e+06
# Epoch 76/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.1350e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.1473e+06
# Epoch 77/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.1617e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.1752e+06
# Epoch 78/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.1910e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.2032e+06
# Epoch 79/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.2183e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.2311e+06
# Epoch 80/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.2456e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.2590e+06
# Epoch 81/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.2750e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.2869e+06
# Epoch 82/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.3032e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.3149e+06
# Epoch 83/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.3298e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.3428e+06
# Epoch 84/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.3584e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.3707e+06
# Epoch 85/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.3850e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.3986e+06
# Epoch 86/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.4130e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.4266e+06
# Epoch 87/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.4413e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.4545e+06
# Epoch 88/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.4685e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.4824e+06
# Epoch 89/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.4976e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.5104e+06
# Epoch 90/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.5260e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.5383e+06
# Epoch 91/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.5554e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.5662e+06
# Epoch 92/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.5811e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.5942e+06
# Epoch 93/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.6092e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.6221e+06
# Epoch 94/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.6361e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.6500e+06
# Epoch 95/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.6636e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.6779e+06
# Epoch 96/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.6936e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.7059e+06
# Epoch 97/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.7212e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.7338e+06
# Epoch 98/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.7506e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.7617e+06
# Epoch 99/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.7763e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.7896e+06
# Epoch 100/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.8046e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.8176e+06
# Epoch 101/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.8337e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.8455e+06
# Epoch 102/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.8615e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.8734e+06
# Epoch 103/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.8912e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.9014e+06
# Epoch 104/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.9190e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.9293e+06
# Epoch 105/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.9442e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.9572e+06
# Epoch 106/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -2.9734e+06 - val_accuracy: 0.0000e+00 - val_loss: -2.9852e+06
# Epoch 107/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.0018e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.0131e+06
# Epoch 108/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.0279e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.0410e+06
# Epoch 109/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.0562e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.0689e+06
# Epoch 110/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.0864e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.0969e+06
# Epoch 111/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.1126e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.1248e+06
# Epoch 112/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.1424e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.1527e+06
# Epoch 113/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.1673e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.1807e+06
# Epoch 114/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.1971e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.2086e+06
# Epoch 115/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.2261e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.2365e+06
# Epoch 116/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.2544e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.2645e+06
# Epoch 117/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.2798e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.2924e+06
# Epoch 118/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.3068e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.3203e+06
# Epoch 119/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.3342e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.3482e+06
# Epoch 120/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.3661e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.3761e+06
# Epoch 121/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.3928e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.4041e+06
# Epoch 122/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.4197e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.4320e+06
# Epoch 123/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.4499e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.4599e+06
# Epoch 124/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.4775e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.4879e+06
# Epoch 125/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.5025e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.5158e+06
# Epoch 126/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.5301e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.5437e+06
# Epoch 127/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.5606e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.5716e+06
# Epoch 128/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.5862e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.5996e+06
# Epoch 129/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.6147e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.6275e+06
# Epoch 130/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.6430e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.6554e+06
# Epoch 131/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.6718e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.6834e+06
# Epoch 132/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.7008e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.7113e+06
# Epoch 133/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.7293e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.7392e+06
# Epoch 134/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.7553e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.7672e+06
# Epoch 135/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.7818e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.7951e+06
# Epoch 136/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.8125e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.8230e+06
# Epoch 137/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.8397e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.8509e+06
# Epoch 138/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.8638e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.8788e+06
# Epoch 139/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.8950e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.9068e+06
# Epoch 140/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.9228e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.9347e+06
# Epoch 141/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.9533e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.9626e+06
# Epoch 142/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -3.9790e+06 - val_accuracy: 0.0000e+00 - val_loss: -3.9906e+06
# Epoch 143/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.0049e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.0185e+06
# Epoch 144/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.0345e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.0464e+06
# Epoch 145/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.0618e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.0743e+06
# Epoch 146/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.0893e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.1023e+06
# Epoch 147/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.1199e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.1302e+06
# Epoch 148/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.1473e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.1581e+06
# Epoch 149/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.1744e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.1861e+06
# Epoch 150/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.2042e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.2140e+06
# Epoch 151/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.2328e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.2419e+06
# Epoch 152/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.2610e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.2699e+06
# Epoch 153/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.2865e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.2978e+06
# Epoch 154/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.3140e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.3257e+06
# Epoch 155/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.3429e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.3536e+06
# Epoch 156/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.3714e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.3816e+06
# Epoch 157/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.4015e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.4095e+06
# Epoch 158/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.4261e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.4374e+06
# Epoch 159/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.4583e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.4654e+06
# Epoch 160/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.4826e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.4933e+06
# Epoch 161/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.5125e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.5212e+06
# Epoch 162/200
# 500/500 - 1s - 1ms/step - accuracy: 0.0000e+00 - loss: -4.5374e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.5492e+06
# Epoch 163/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.5650e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.5771e+06
# Epoch 164/200
# 500/500 - 1s - 1ms/step - accuracy: 0.0000e+00 - loss: -4.5968e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.6050e+06
# Epoch 165/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.6201e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.6329e+06
# Epoch 166/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.6522e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.6609e+06
# Epoch 167/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.6780e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.6888e+06
# Epoch 168/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.7061e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.7167e+06
# Epoch 169/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.7342e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.7446e+06
# Epoch 170/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.7611e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.7726e+06
# Epoch 171/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.7904e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.8005e+06
# Epoch 172/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.8149e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.8284e+06
# Epoch 173/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.8468e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.8564e+06
# Epoch 174/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.8742e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.8843e+06
# Epoch 175/200
# 500/500 - 1s - 1ms/step - accuracy: 0.0000e+00 - loss: -4.8997e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.9122e+06
# Epoch 176/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.9296e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.9401e+06
# Epoch 177/200
# 500/500 - 1s - 1ms/step - accuracy: 0.0000e+00 - loss: -4.9566e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.9681e+06
# Epoch 178/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -4.9840e+06 - val_accuracy: 0.0000e+00 - val_loss: -4.9960e+06
# Epoch 179/200
# 500/500 - 1s - 1ms/step - accuracy: 0.0000e+00 - loss: -5.0112e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.0239e+06
# Epoch 180/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -5.0417e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.0518e+06
# Epoch 181/200
# 500/500 - 1s - 1ms/step - accuracy: 0.0000e+00 - loss: -5.0728e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.0798e+06
# Epoch 182/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -5.0979e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.1077e+06
# Epoch 183/200
# 500/500 - 1s - 1ms/step - accuracy: 0.0000e+00 - loss: -5.1232e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.1356e+06
# Epoch 184/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -5.1548e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.1636e+06
# Epoch 185/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -5.1832e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.1915e+06
# Epoch 186/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -5.2081e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.2194e+06
# Epoch 187/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -5.2362e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.2474e+06
# Epoch 188/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -5.2675e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.2753e+06
# Epoch 189/200
# 500/500 - 1s - 1ms/step - accuracy: 0.0000e+00 - loss: -5.2924e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.3032e+06
# Epoch 190/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -5.3201e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.3311e+06
# Epoch 191/200
# 500/500 - 1s - 1ms/step - accuracy: 0.0000e+00 - loss: -5.3476e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.3591e+06
# Epoch 192/200
# 500/500 - 1s - 1ms/step - accuracy: 0.0000e+00 - loss: -5.3805e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.3870e+06
# Epoch 193/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -5.4049e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.4149e+06
# Epoch 194/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -5.4325e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.4429e+06
# Epoch 195/200
# 500/500 - 1s - 1ms/step - accuracy: 0.0000e+00 - loss: -5.4596e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.4708e+06
# Epoch 196/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -5.4918e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.4987e+06
# Epoch 197/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -5.5161e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.5266e+06
# Epoch 198/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -5.5495e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.5546e+06
# Epoch 199/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -5.5703e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.5825e+06
# Epoch 200/200
# 500/500 - 1s - 2ms/step - accuracy: 0.0000e+00 - loss: -5.6015e+06 - val_accuracy: 0.0000e+00 - val_loss: -5.6104e+06

# %%
import xgboost as xgb
import xgboost as xgb

# Prepare the data for XGBoost
X_tyres = tyre_pressure_data.drop(columns=['set_id', 'row_id', 'pressure_1'])  # Drop target column for features
y_tyres = tyre_pressure_data['pressure_1']  # Target column

# Check if there are any missing values and handle them
X_tyres = X_tyres.fillna(X_tyres.mean())
y_tyres = y_tyres.fillna(y_tyres.mean())

# Train XGBoost model
X_dmatrix = xgb.DMatrix(X_tyres, label=y_tyres)
params = {
    'objective': 'reg:squarederror',  # Regression objective for predicting pressure
    'eval_metric': 'rmse',  # Using RMSE for regression
    'max_depth': 5,
    'learning_rate': 0.1,
    'n_estimators': 100
}

xgb_model = xgb.train(params, X_dmatrix, num_boost_round=100)

# Make predictions
y_probs_tyres = xgb_model.predict(X_dmatrix)

# Display predictions
print("Tyre failure probabilities:", y_probs_tyres[:5])
# Out:
# /Users/frantzmoudoute/anaconda3/envs/jax-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [19:46:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Tyre failure probabilities: [243.29605 254.35165 260.32642 252.49661 243.17473]

# %%
failure_threshold = 200  # Example threshold, adjust as per domain knowledge

# Classify tyres based on predicted pressure
tyre_failures = y_probs_tyres < failure_threshold  # Boolean array of failure predictions
print("Tyre failure predictions (True = failure, False = normal):", tyre_failures[:10])

# Normalize predicted pressures to a probability scale (0 to 1)
min_pressure = min(y_probs_tyres)
max_pressure = max(y_probs_tyres)
normalized_probs = (y_probs_tyres - min_pressure) / (max_pressure - min_pressure)

# Now `normalized_probs` will be between 0 and 1, indicating relative failure probabilities
print("Normalized Tyre failure probabilities:", normalized_probs[:5])
# Out:
# Tyre failure predictions (True = failure, False = normal): [False False False False False False False False False False]
# Normalized Tyre failure probabilities: [0.36748934 0.548976   0.6470566  0.518524   0.36549774]

# %%
# Predict failure probabilities for Bogie dataset (using LSTM)
y_probs_bogie = model.predict(X_bogie_scaled)

# Predict failure probabilities for Tyre dataset (using XGBoost)
X_tyres_dmatrix = xgb.DMatrix(X_tyres)
y_probs_tyres = xgb_model.predict(X_tyres_dmatrix)
# Out:
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 1s 484us/step

# %%
# Assuming that all the models give us probabilities of failure for each set_id
# Create DataFrame for predictions

bogie_prob_df = pd.DataFrame({
    'set_id': bogie_data['set_id'],
    'bogie_prob': y_probs_bogie.flatten()
})

tyre_prob_df = pd.DataFrame({
    'set_id': tyre_pressure_data['set_id'],
    'tyre_prob': y_probs_tyres
})

# Merge the predictions from both models
combined_prob_df = pd.merge(bogie_prob_df, tyre_prob_df, on='set_id', how='outer')

# Combine the probabilities to create a final health indicator (you can use a weighted average if needed)
combined_prob_df['health_indicator'] = (combined_prob_df['bogie_prob'] + combined_prob_df['tyre_prob']) / 2

# Rank the health of each system
combined_prob_df['health_rank'] = combined_prob_df['health_indicator'].rank(ascending=False)

# Display the final health ranking
print(combined_prob_df[['set_id', 'health_indicator', 'health_rank']].head())
# Out:
#    set_id  health_indicator  health_rank
# 0     0.0        122.148026    1713500.5
# 1     0.0        127.675827     861900.5
# 2     0.0        130.663208     469100.5
# 3     0.0        126.748306    1027900.5
# 4     0.0        122.087364    1720700.5
